# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from scipy.sparse import csr_matrix
import scipy.sparse as sp
from sklearn.model_selection import train_test_split

# %%
city = 'foursquare_nyc'
df = pd.read_csv('../' + city + '/foursquare_mapped_NYC.geo')
bvc = df['venue_category_name'].value_counts() >= 20
bvc = bvc[bvc > 0].index
df = df[df['venue_category_name'].isin(bvc)]
df.reset_index(inplace=True, drop=True)

brand2id, cate12id, cate22id = {}, {}, {}
for idx, row in df.iterrows():
    brand, cate_1, cate_2 = row['venue_category_name'], row['topCate'], row['region_id']
    if brand not in brand2id.keys():
        brand2id[brand] = len(brand2id)
    if cate_1 not in cate12id.keys():
        cate12id[cate_1] = len(cate12id)
    if cate_2 not in cate22id.keys():
        cate22id[cate_2] = len(cate22id)

brand2id = pd.DataFrame({'venue_category_name': list(
    brand2id.keys()), 'Brand_ID': list(brand2id.values())})
cate12id = pd.DataFrame(
    {'topCate': list(cate12id.keys()), 'Cate1_ID': list(cate12id.values())})
cate22id = pd.DataFrame(
    {'region_id': list(cate22id.keys()), 'Region_ID': list(cate22id.values())})


df = df.merge(brand2id, on=['venue_category_name'], how='left')
df = df.merge(cate12id, on=['topCate'], how='left')
df = df.merge(cate22id, on=['region_id'], how='left')

df = df[['geo_id', 'venue_category_name', 'Brand_ID', 'Cate1_ID', 'Region_ID']]

print(df['Brand_ID'].max())
print(df['Region_ID'].max())
# Out:
# 94
# 1602

# %%
print(df['Brand_ID'].max())
print(df['Region_ID'].max())
# Out:
# 94
# 1602

# %%
df.nunique()
# Out:
# geo_id                 9067
# venue_category_name      95
# Brand_ID                 95
# Cate1_ID                  9
# Region_ID              1603
# dtype: int64

# %%
np.random.seed(42)
train_data, test_data = [], []
for i in range(df['Brand_ID'].max() + 1):
    data = df[df['Brand_ID'] == i]
    x_train, x_test, y_train, y_test = train_test_split(
        data[['Brand_ID', 'Cate1_ID']], data['Region_ID'],
        test_size=0.2, random_state=42)
    x_train['Region_ID'] = y_train
    x_test['Region_ID'] = y_test
    train_data.append(x_train)
    test_data.append(x_test)

# %%
train_data, test_data = pd.concat(
    train_data, axis=0), pd.concat(test_data, axis=0)
print(train_data.shape, "train_data.shape")
print(test_data.shape, "test_data.shape")
# Out:
# (7217, 3) train_data.shape
# (1850, 3) test_data.shape

# %%
import os


dir_path = os.path.join(city, 'split')

if not os.path.exists(dir_path):
    os.makedirs(dir_path)
train_data.to_pickle(os.path.join(dir_path, 'train.pkl'))
test_data.to_pickle(os.path.join(dir_path, 'test.pkl'))

# %%
city = 'foursquare_nyc'
df = pd.read_csv('../' + city + '/foursquare_mapped_NYC.geo')
df
# Out:
#       Unnamed: 0  geo_id   type       Long        Lat  \
# 0              0       0  Point -74.003139  40.733596
# 1              1       1  Point -73.967644  40.756368
# 2              2       2  Point -73.981393  40.724827
# 3              3       3  Point -74.006020  40.739685
# 4              4       4  Point -73.990817  40.718363
# ...          ...     ...    ...        ...        ...
# 9881        9984    9984  Point -74.108426  40.889077
# 9882        9985    9985  Point -73.984446  40.728397
# 9883        9986    9986  Point -74.004831  40.741677
# 9884        9987    9987  Point -73.981934  40.757790
# 9885        9988    9988  Point -73.997669  40.717125
#
#              venue_category_id                       venue_category_name  \
# 0     4bf58dd8d48988d1e7931735                               Music Venue
# 1     4bf58dd8d48988d11d941735                                       Bar
# 2     4bf58dd8d48988d118941735                                       Bar
# 3     4bf58dd8d48988d10c941735                         French Restaurant
# 4     4bf58dd8d48988d116941735                                       Bar
# ...                        ...                                       ...
# 9881  4bf58dd8d48988d124941735                                    Office
# 9882  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 9883  4f2a23984b9023bd5841ed2c                             Moving Target
# 9884  4bf58dd8d48988d162941735                      Other Great Outdoors
# 9885  50aa9e094b90af0d42d5de0d                                      City
#
#       region_id  cate_id                      topCate
# 0           689      145         Arts & Entertainment
# 1           838       21               Nightlife Spot
# 2           596       21               Nightlife Spot
# 3           690       89                         Food
# 4           559       21               Nightlife Spot
# ...         ...      ...                          ...
# 9881       1489      150  Professional & Other Places
# 9882        642      172                    Residence
# 9883        741      142           Travel & Transport
# 9884        840      151        Outdoors & Recreation
# 9885        560       49        Outdoors & Recreation
#
# [9886 rows x 10 columns]

# %%
df.nunique()
# Out:
# Unnamed: 0             9886
# geo_id                 9886
# type                      1
# Long                   8850
# Lat                    9518
# venue_category_id       333
# venue_category_name     219
# region_id              1671
# cate_id                 219
# topCate                   9
# dtype: int64

# %%
city = 'foursquare_nyc'
dyna = pd.read_csv('../' + city + '/' + city+'.dyna')
dyna
# Out:
#         dyna_id        type                  time  entity_id  location
# 0             0  trajectory  2012-04-03T14:00:09Z          0      1230
# 1             1  trajectory  2012-04-03T14:00:25Z          1      1879
# 2             2  trajectory  2012-04-03T14:02:24Z          2      6161
# 3             3  trajectory  2012-04-03T14:03:00Z          3      6859
# 4             4  trajectory  2012-04-03T14:04:00Z          4      4017
# ...         ...         ...                   ...        ...       ...
# 179463   179463  trajectory  2013-02-15T21:29:11Z        113         0
# 179464   179464  trajectory  2013-02-15T21:29:11Z        568       964
# 179465   179465  trajectory  2013-02-15T21:31:35Z        490      5135
# 179466   179466  trajectory  2013-02-15T21:33:16Z        691      9933
# 179467   179467  trajectory  2013-02-15T21:34:31Z       1064       907
#
# [179468 rows x 5 columns]

# %%
dyna = dyna.sort_values(['User', 'timestamp'])

# %%
threshold = 20
bvc = df['cate_id'].value_counts() >= threshold
bvc = bvc[bvc > 0].index
df = df[df['cate_id'].isin(bvc)]
df.reset_index(inplace=True, drop=True)

# %%
brand2id, cate12id, cate22id = {}, {}, {}
for idx, row in df.iterrows():
    brand, cate_1, cate_2 = row['Brand'], row['topCate'], row['region_id']
    if brand not in brand2id.keys():
        brand2id[brand] = len(brand2id)
    if cate_1 not in cate12id.keys():
        cate12id[cate_1] = len(cate12id)
    if cate_2 not in cate22id.keys():
        cate22id[cate_2] = len(cate22id)

brand2id = pd.DataFrame(
    {'Brand': list(brand2id.keys()), 'Brand_ID': list(brand2id.values())})
cate12id = pd.DataFrame(
    {'cate_1': list(cate12id.keys()), 'Cate1_ID': list(cate12id.values())})
cate22id = pd.DataFrame(
    {'cate_2': list(cate22id.keys()), 'Cate2_ID': list(cate22id.values())})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32024\2120476436.py in <module>
#       1 brand2id, cate12id, cate22id  = {}, {}, {}
#       2 for idx, row in df.iterrows():
# ----> 3     brand, cate_1, cate_2= row['Brand'], row['topCate'], row['region_id']
#       4     if brand not in brand2id.keys():
#       5         brand2id[brand] = len(brand2id)
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Brand'

# %%
cate12id = {}
for idx, row in df.iterrows():
    cate_1 = row['topCate']
    if cate_1 not in cate12id.keys():
        cate12id[cate_1] = len(cate12id)
cate12id = pd.DataFrame(
    {'topCate': list(cate12id.keys()), 'topCate_ID': list(cate12id.values())})
df = df.merge(cate12id, on=['topCate'], how='left')
df
# df = df[['geo_id', 'venue_category_name', 'cate_id', 'topCate_ID', 'region_id']]
# Out:
#       Unnamed: 0  geo_id   type       Long        Lat  \
# 0              0       0  Point -74.003139  40.733596
# 1              1       1  Point -73.967644  40.756368
# 2              2       2  Point -73.981393  40.724827
# 3              3       3  Point -74.006020  40.739685
# 4              4       4  Point -73.990817  40.718363
# ...          ...     ...    ...        ...        ...
# 9062        9981    9981  Point -73.943611  40.703281
# 9063        9984    9984  Point -74.108426  40.889077
# 9064        9985    9985  Point -73.984446  40.728397
# 9065        9986    9986  Point -74.004831  40.741677
# 9066        9987    9987  Point -73.981934  40.757790
#
#              venue_category_id                       venue_category_name  \
# 0     4bf58dd8d48988d1e7931735                               Music Venue
# 1     4bf58dd8d48988d11d941735                                       Bar
# 2     4bf58dd8d48988d118941735                                       Bar
# 3     4bf58dd8d48988d10c941735                         French Restaurant
# 4     4bf58dd8d48988d116941735                                       Bar
# ...                        ...                                       ...
# 9062  4bf58dd8d48988d1f1931735                     General Entertainment
# 9063  4bf58dd8d48988d124941735                                    Office
# 9064  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 9065  4f2a23984b9023bd5841ed2c                             Moving Target
# 9066  4bf58dd8d48988d162941735                      Other Great Outdoors
#
#       region_id  cate_id                      topCate  topCate_ID_x  \
# 0           689      145         Arts & Entertainment             0
# 1           838       21               Nightlife Spot             1
# 2           596       21               Nightlife Spot             1
# 3           690       89                         Food             2
# 4           559       21               Nightlife Spot             1
# ...         ...      ...                          ...           ...
# 9062        481       98         Arts & Entertainment             0
# 9063       1489      150  Professional & Other Places             3
# 9064        642      172                    Residence             8
# 9065        741      142           Travel & Transport             4
# 9066        840      151        Outdoors & Recreation             6
#
#       topCate_ID_y  topCate_ID
# 0                0           0
# 1                1           1
# 2                1           1
# 3                2           2
# 4                1           1
# ...            ...         ...
# 9062             0           0
# 9063             3           3
# 9064             8           8
# 9065             4           4
# 9066             6           6
#
# [9067 rows x 13 columns]

# %%
df = df[['geo_id', 'venue_category_name', 'cate_id', 'topCate_ID', 'region_id']]

# %%
df = df.rename(columns={
    'venue_category_name': 'Name',
    'cate_id': 'Brand_ID',
    'topCate_ID': 'Cate1_ID',
    'region_id': 'Region_ID'
})

# %%
df
# Out:
#       geo_id                                      Name  Brand_ID  Cate1_ID  \
# 0          0                               Music Venue       145         0
# 1          1                                       Bar        21         1
# 2          2                                       Bar        21         1
# 3          3                         French Restaurant        89         2
# 4          4                                       Bar        21         1
# ...      ...                                       ...       ...       ...
# 9062    9981                     General Entertainment        98         0
# 9063    9984                                    Office       150         3
# 9064    9985  Residential Building (Apartment / Condo)       172         8
# 9065    9986                             Moving Target       142         4
# 9066    9987                      Other Great Outdoors       151         6
#
#       Region_ID
# 0           689
# 1           838
# 2           596
# 3           690
# 4           559
# ...         ...
# 9062        481
# 9063       1489
# 9064        642
# 9065        741
# 9066        840
#
# [9067 rows x 5 columns]

# %%
df.nunique()
# Out:
# geo_id       9067
# Name           95
# Brand_ID       95
# Cate1_ID        9
# Region_ID    1603
# dtype: int64

# %%
df[df['Brand_ID'] == 0]
# Out:
# Empty DataFrame
# Columns: [geo_id, Name, Brand_ID, Cate1_ID, Region_ID]
# Index: []

# %%
np.random.seed(42)
train_data, test_data = [], []
for i in range(df['Brand_ID'].max() + 1):
    data = df[df['Brand_ID'] == i]
    print(data)
    x_train, x_test, y_train, y_test = train_test_split(
        data[['Brand_ID', 'Cate1_ID']], data['Region_ID'],
        test_size=0.2, random_state=42)
    x_train['Region_ID'] = y_train
    x_test['Region_ID'] = y_test
    train_data.append(x_train)
    test_data.append(x_test)
train_data, test_data = pd.concat(
    train_data, axis=0), pd.concat(test_data, axis=0)
print(train_data.shape, "train_data.shape")
print(test_data.shape, "test_data.shape")
# Out:
# Empty DataFrame
# Columns: [geo_id, Name, Brand_ID, Cate1_ID, Region_ID]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32024\2930218213.py in <module>
#       6     x_train, x_test, y_train, y_test = train_test_split(
#       7         data[['Brand_ID', 'Cate1_ID']], data['Region_ID'],
# ----> 8         test_size=0.2, random_state=42)
#       9     x_train['Region_ID'] = y_train
#      10     x_test['Region_ID'] = y_test
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2419     n_samples = _num_samples(arrays[0])
#    2420     n_train, n_test = _validate_shuffle_split(
# -> 2421         n_samples, test_size, train_size, default_test_size=0.25
#    2422     )
#    2423
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2099             "With n_samples={}, test_size={} and train_size={}, the "
#    2100             "resulting train set will be empty. Adjust any of the "
# -> 2101             "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2102         )
#    2103
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
df
# Out:
#       Unnamed: 0  geo_id   type       Long        Lat  \
# 0              0       0  Point -74.003139  40.733596
# 1              1       1  Point -73.967644  40.756368
# 2              2       2  Point -73.981393  40.724827
# 3              3       3  Point -74.006020  40.739685
# 4              4       4  Point -73.990817  40.718363
# ...          ...     ...    ...        ...        ...
# 9062        9981    9981  Point -73.943611  40.703281
# 9063        9984    9984  Point -74.108426  40.889077
# 9064        9985    9985  Point -73.984446  40.728397
# 9065        9986    9986  Point -74.004831  40.741677
# 9066        9987    9987  Point -73.981934  40.757790
#
#              venue_category_id                       venue_category_name  \
# 0     4bf58dd8d48988d1e7931735                               Music Venue
# 1     4bf58dd8d48988d11d941735                                       Bar
# 2     4bf58dd8d48988d118941735                                       Bar
# 3     4bf58dd8d48988d10c941735                         French Restaurant
# 4     4bf58dd8d48988d116941735                                       Bar
# ...                        ...                                       ...
# 9062  4bf58dd8d48988d1f1931735                     General Entertainment
# 9063  4bf58dd8d48988d124941735                                    Office
# 9064  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 9065  4f2a23984b9023bd5841ed2c                             Moving Target
# 9066  4bf58dd8d48988d162941735                      Other Great Outdoors
#
#       region_id  cate_id                      topCate  topCate_ID
# 0           689      145         Arts & Entertainment           0
# 1           838       21               Nightlife Spot           1
# 2           596       21               Nightlife Spot           1
# 3           690       89                         Food           2
# 4           559       21               Nightlife Spot           1
# ...         ...      ...                          ...         ...
# 9062        481       98         Arts & Entertainment           0
# 9063       1489      150  Professional & Other Places           3
# 9064        642      172                    Residence           8
# 9065        741      142           Travel & Transport           4
# 9066        840      151        Outdoors & Recreation           6
#
# [9067 rows x 11 columns]

# %%
print(df['geo_id'].max())
print(df['region_id'].max())
# Out:
# 9988
# 1681

# %%
np.random.seed(42)
train_data, test_data = [], []
for i in range(df['geo_id'].max() + 1):
    data = df[df['geo_id'] == i]
    x_train, x_test, y_train, y_test = train_test_split(
        data[['geo_id', 'cate_id']], data['region_id'],
        test_size=0.2, random_state=42)
    x_train['region_id'] = y_train
    x_test['region_id'] = y_test
    train_data.append(x_train)
    test_data.append(x_test)
train_data, test_data = pd.concat(
    train_data, axis=0), pd.concat(test_data, axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32024\2633515734.py in <module>
#       5     x_train, x_test, y_train, y_test = train_test_split(
#       6         data[['geo_id', 'cate_id']], data['region_id'],
# ----> 7         test_size=0.2, random_state=42)
#       8     x_train['region_id'] = y_train
#       9     x_test['region_id'] = y_test
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2419     n_samples = _num_samples(arrays[0])
#    2420     n_train, n_test = _validate_shuffle_split(
# -> 2421         n_samples, test_size, train_size, default_test_size=0.25
#    2422     )
#    2423
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2099             "With n_samples={}, test_size={} and train_size={}, the "
#    2100             "resulting train set will be empty. Adjust any of the "
# -> 2101             "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2102         )
#    2103
#
# ValueError: With n_samples=1, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
bvc = bvc[bvc > 0].index
df = df[df['Brand'].isin(bvc)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32024\2519696297.py in <module>
#       1 bvc = bvc[bvc > 0].index
# ----> 2 df = df[df['Brand'].isin(bvc)]
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# e:\Anaconda\envs\deeplearning\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Brand'
